# %%
base) anurag@anurag-Lenovo-ideapad-320-15IKB:~$ git clone https://github.com/anu1602/GIT0.git
Cloning into 'GIT0'...
warning: You appear to have cloned an empty repository.
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~$ cd GIT0/
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ ls
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ touch hello.html
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ code .
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ ls
hello.html

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git add hello.html
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git commit -m "Added hello.html"
[master (root-commit) 02f347a] Added hello.html
 1 file changed, 9 insertions(+)
 create mode 100644 hello.html

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git status
On branch master
Your branch is based on 'origin/master', but the upstream is gone.
  (use "git branch --unset-upstream" to fixup)

nothing to commit, working tree clean

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git push
Username for 'https://github.com': anu1602
Password for 'https://anu1602@github.com': 
Counting objects: 3, done.
Delta compression using up to 4 threads.
Compressing objects: 100% (2/2), done.
Writing objects: 100% (3/3), 302 bytes | 302.00 KiB/s, done.
Total 3 (delta 0), reused 0 (delta 0)
To https://github.com/anu1602/GIT0.git
 * [new branch]      master -> master

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git pull
remote: Enumerating objects: 5, done.
remote: Counting objects: 100% (5/5), done.
remote: Compressing objects: 100% (2/2), done.
remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
Unpacking objects: 100% (3/3), done.
From https://github.com/anu1602/GIT0
   02f347a..4305e72  master     -> origin/master
Updating 02f347a..4305e72
Fast-forward
 hello.html | 4 ++--
 1 file changed, 2 insertions(+), 2 deletions(-)

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git add hello.html
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git commit -m "Add a third line"
[master af2c21f] Add a third line
 1 file changed, 1 insertion(+), 1 deletion(-)
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git pull
remote: Enumerating objects: 5, done.
remote: Counting objects: 100% (5/5), done.
remote: Compressing objects: 100% (2/2), done.
remote: Total 3 (delta 1), reused 0 (delta 0), pack-reused 0
Unpacking objects: 100% (3/3), done.
From https://github.com/anu1602/GIT0
   4305e72..3c23de5  master     -> origin/master
Auto-merging hello.html
CONFLICT (content): Merge conflict in hello.html
Automatic merge failed; fix conflicts and then commit the result.
   
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git add hello.html
    
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$  git commit -m "Fix merge conflict"
[master 785dd78] Fix merge conflict

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git status
On branch master
Your branch and 'origin/master' have diverged,
and have 1 and 1 different commits each, respectively.
  (use "git pull" to merge the remote branch into yours)

You have unmerged paths.
  (fix conflicts and run "git commit")
  (use "git merge --abort" to abort the merge)

Unmerged paths:
  (use "git add <file>..." to mark resolution)

	both modified:   hello.html

no changes added to commit (use "git add" and/or "git commit -a")

(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git log
commit 785dd78737d01205335b6e9cf00bc74a1d0421c3 (HEAD -> master)
Merge: af2c21f 3c23de5
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Sun Jun 28 12:25:50 2020 +0530

    Fix merge conflict

commit 3c23de5d92e40df35ca4038350aed7b06e6820e6 (origin/master)
Author: Anurag Pandey <54531646+anu1602@users.noreply.github.com>
Date:   Sun Jun 28 12:08:35 2020 +0530

    Update hello.html

commit af2c21fd3315d3a44c8b4e51d634275530e41095
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Sun Jun 28 12:07:16 2020 +0530

    Add a third line

commit 4305e7269782dcab3544779fc2aa993362337f22
Author: Anurag Pandey <54531646+anu1602@users.noreply.github.com>
Date:   Sun Jun 28 12:02:29 2020 +0530

    Update hello.html

commit 02f347adccdf1c7bb69e1715f711608dd2ba1f9b
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Sun Jun 28 11:47:05 2020 +0530

    Added hello.html

# %%
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git reset --hard 02f347adcc
HEAD is now at 02f347a Added hello.html

# %%
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git reflog
02f347a (HEAD -> master) HEAD@{0}: reset: moving to 02f347adcc
785dd78 HEAD@{1}: commit (merge): Fix merge conflict
af2c21f HEAD@{2}: commit: Add a third line
4305e72 HEAD@{3}: pull: Fast-forward
02f347a (HEAD -> master) HEAD@{4}: commit (initial): Added hello.html

# %%
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~$ cd GIT0/
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ code .
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ ls
git0.ipynb  hello.html  index.html
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git add index.html
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git commit -m "Changed the body message"
[master 95d705e] Changed the body message
 1 file changed, 9 insertions(+)
 create mode 100644 index.html
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch
* master
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch feature
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch
  feature
* master
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git checkout feature
Switched to branch 'feature'
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch
* feature
  master
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git commit -am "Added another line"
[feature 873a0c8] Added another line
 1 file changed, 2 insertions(+), 1 deletion(-)
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch
* feature
  master
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git checkout master
error: Your local changes to the following files would be overwritten by checkout:
	index.html
Please commit your changes or stash them before you switch branches.
Aborting
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git commit -am "Added another line"
[feature b3f4147] Added another line
 1 file changed, 1 insertion(+), 1 deletion(-)
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch
* feature
  master
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git checkout master
Switched to branch 'master'
Your branch and 'origin/master' have diverged,
and have 1 and 2 different commits each, respectively.
  (use "git pull" to merge the remote branch into yours)
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git log
commit 95d705ec6d03db6cc60bfb9196f20efa2770f056 (HEAD -> master)
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Mon Jun 29 11:03:29 2020 +0530

    Changed the body message

commit 02f347adccdf1c7bb69e1715f711608dd2ba1f9b
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Sun Jun 28 11:47:05 2020 +0530

    Added hello.html
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git checkout feature
Switched to branch 'feature'
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git log
commit b3f41477e9dbf6a4989f9d8d8750be31b01fc193 (HEAD -> feature)
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Mon Jun 29 14:09:32 2020 +0530

    Added another line

commit 873a0c82816205d3ff7de290025d637611086bc8
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Mon Jun 29 14:06:15 2020 +0530

    Added another line

commit 95d705ec6d03db6cc60bfb9196f20efa2770f056 (master)
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Mon Jun 29 11:03:29 2020 +0530

    Changed the body message

commit 02f347adccdf1c7bb69e1715f711608dd2ba1f9b
Author: anu1602 <anuragpandey791@gmail.com>
Date:   Sun Jun 28 11:47:05 2020 +0530

    Added hello.html
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git checkout master
Switched to branch 'master'
Your branch and 'origin/master' have diverged,
and have 1 and 2 different commits each, respectively.
  (use "git pull" to merge the remote branch into yours)
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git merge feature
Updating 95d705e..b3f4147
Fast-forward
 index.html | 3 ++-
 1 file changed, 2 insertions(+), 1 deletion(-)
(base) anurag@anurag-Lenovo-ideapad-320-15IKB:~/GIT0$ git branch
  feature
* master
